# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
import pandas as pd

# %%
url = "https://www.flipkart.com/mixerjuicergrinders/pr?sid=j9e%2Cm38%2C7ek&otracker=nmenu_sub_Appliances_0_Mixer%2FJuicer%2FGrinder&otracker=nmenu_sub_TVs%20%26%20Appliances_0_Juicer%2FMixer%2FGrinder"

# %%
allow = requests.get(url)

# %%
print(allow)
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(allow.text)

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
mixer_name=soup.select("._4rR01T")

# %%
mixer_name
# Out:
# [<div class="_4rR01T">ZunVolt Power MG5 500 Mixer Grinder (3 Jars, White, Turquoise)</div>,
#  <div class="_4rR01T">Flipkart SmartBuy Neo Power Chef 600 W Juicer Mixer Grinder (4 Jars, Black, Red)</div>,
#  <div class="_4rR01T">Bajaj GX1 500 W Mixer Grinder</div>,
#  <div class="_4rR01T">Lifelong LLCMB02 500 W Mixer Grinder (White, 3 Jars) &amp; 1100 W Dry Iron (White, Blue) Super Combo</div>,
#  <div class="_4rR01T">Butterfly Plus Rapid 750 W Mixer Grinder (5 Jars, Ink Blue)</div>,
#  <div class="_4rR01T">Flipkart SmartBuy PowerChef Premium 500 W Mixer Grinder</div>,
#  <div class="_4rR01T">Butterfly Arrow 500 W Mixer Grinder (3 Jars, Grey)</div>,
#  <div class="_4rR01T">HAVELLS GHFMGDVV075 Klassic 750 W Mixer Grinder (4 Jars, White - Lavender)</div>,
#  <div class="_4rR01T">Croma by Croma MIXER GRINDER CRAK4184 500 W Mixer Grinder 500 Mixer Grinder (3 Jars, White, Purple)</div>,
#  <div class="_4rR01T">Prestige Flash Atlas 500 W Mixer Grinder (3 Jars, White, Black)</div>,
# ...

# %%
mixer=[]

# %%
for item in mixer_name:
    mixer.append(item.text)

# %%
mixer
# Out:
# ['ZunVolt Power MG5 500 Mixer Grinder (3 Jars, White, Turquoise)',
#  'Flipkart SmartBuy Neo Power Chef 600 W Juicer Mixer Grinder (4 Jars, Black, Red)',
#  'Bajaj GX1 500 W Mixer Grinder',
#  'Lifelong LLCMB02 500 W Mixer Grinder (White, 3 Jars) & 1100 W Dry Iron (White, Blue) Super Combo',
#  'Butterfly Plus Rapid 750 W Mixer Grinder (5 Jars, Ink Blue)',
#  'Flipkart SmartBuy PowerChef Premium 500 W Mixer Grinder',
#  'Butterfly Arrow 500 W Mixer Grinder (3 Jars, Grey)',
#  'HAVELLS GHFMGDVV075 Klassic 750 W Mixer Grinder (4 Jars, White - Lavender)',
#  'Croma by Croma MIXER GRINDER CRAK4184 500 W Mixer Grinder 500 Mixer Grinder (3 Jars, White, Purple)',
#  'Prestige Flash Atlas 500 W Mixer Grinder (3 Jars, White, Black)',
#  'Prestige Plus Atlas 750 W Juicer Mixer Grinder (4 Jars, Blue, White)',
#  'HAVELLS GHFMGDWV075 Klassic 750 W Mixer Grinder (3 Jars, White - Lavender)',
#  'Butterfly Rapid 750 W Juicer Mixer Grinder (4 Jars, Black)',
# ...

# %%
mixer_rate=soup.select("._1_WHN1")

# %%
mixer_rate
# Out:
# [<div class="_30jeq3 _1_WHN1">₹1,290</div>,
#  <div class="_30jeq3 _1_WHN1">₹1,809</div>,
#  <div class="_30jeq3 _1_WHN1">₹2,199</div>,
#  <div class="_30jeq3 _1_WHN1">₹1,716</div>,
#  <div class="_30jeq3 _1_WHN1">₹3,249</div>,
#  <div class="_30jeq3 _1_WHN1">₹1,509</div>,
#  <div class="_30jeq3 _1_WHN1">₹1,849</div>,
#  <div class="_30jeq3 _1_WHN1">₹3,849</div>,
#  <div class="_30jeq3 _1_WHN1">₹1,290</div>,
#  <div class="_30jeq3 _1_WHN1">₹1,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹2,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹3,579</div>,
#  <div class="_30jeq3 _1_WHN1">₹2,799</div>,
#  <div class="_30jeq3 _1_WHN1">₹3,899</div>,
#  <div class="_30jeq3 _1_WHN1">₹3,199</div>,
#  <div class="_30jeq3 _1_WHN1">₹1,875</div>,
#  <div class="_30jeq3 _1_WHN1">₹1,299</div>,
#  <div class="_30jeq3 _1_WHN1">₹3,263</div>,
#  <div class="_30jeq3 _1_WHN1">₹4,269</div>,
#  <div class="_30jeq3 _1_WHN1">₹1,869</div>,
#  <div class="_30jeq3 _1_WHN1">₹3,499</div>,
# ...

# %%
rate=[]

# %%
for item in mixer_rate:
    rate.append(item.text)

# %%
rate
# Out:
# ['₹1,290',
#  '₹1,809',
#  '₹2,199',
#  '₹1,716',
#  '₹3,249',
#  '₹1,509',
#  '₹1,849',
#  '₹3,849',
#  '₹1,290',
#  '₹1,999',
#  '₹2,999',
#  '₹3,579',
#  '₹2,799',
#  '₹3,899',
#  '₹3,199',
#  '₹1,875',
#  '₹1,299',
#  '₹3,263',
#  '₹4,269',
#  '₹1,869',
#  '₹3,499',
#  '₹1,749',
#  '₹3,499',
#  '₹2,590']

# %%
mixer=pd.DataFrame(mixer_name,columns=["mixer_names"])

# %%
mixer["price"]= mixer_rate

# %%
mixer.to_csv("VAC.csv")

# %%
mixer
# Out:
#                                           mixer_names     price
# 0   ZunVolt Power MG5 500 Mixer Grinder (3 Jars, W...  [₹1,290]
# 1   Flipkart SmartBuy Neo Power Chef 600 W Juicer ...  [₹1,809]
# 2                       Bajaj GX1 500 W Mixer Grinder  [₹2,199]
# 3   Lifelong LLCMB02 500 W Mixer Grinder (White, 3...  [₹1,716]
# 4   Butterfly Plus Rapid 750 W Mixer Grinder (5 Ja...  [₹3,249]
# 5   Flipkart SmartBuy PowerChef Premium 500 W Mixe...  [₹1,509]
# 6   Butterfly Arrow 500 W Mixer Grinder (3 Jars, G...  [₹1,849]
# 7   HAVELLS GHFMGDVV075 Klassic 750 W Mixer Grinde...  [₹3,849]
# 8   Croma by Croma MIXER GRINDER CRAK4184 500 W Mi...  [₹1,290]
# 9   Prestige Flash Atlas 500 W Mixer Grinder (3 Ja...  [₹1,999]
# 10  Prestige Plus Atlas 750 W Juicer Mixer Grinder...  [₹2,999]
# 11  HAVELLS GHFMGDWV075 Klassic 750 W Mixer Grinde...  [₹3,579]
# 12  Butterfly Rapid 750 W Juicer Mixer Grinder (4 ...  [₹2,799]
# 13  Preethi Platinum select MG226 Blue Leaf 750 Mi...  [₹3,899]
# ...
